# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Zhiyun Qi**
#
# Business Analyst

# %% [markdown]
# *I am interested in data science because it teaches me lots of practical tools and processes in utilizing and automating data analysis which is something I am currently learning as my Master's degree, thus, I want to enhance my study and background knowledge in technical field.*

# %%
x = 12
y = 26
z = 28
print ((x+y)-z)
# Out:
# 10

# %% [markdown]
# - This course has four modules.
# - The last module is a peer graded assessment.
# 1. Create several markdown cells.
# 2. Create one code cell.
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Inserted an image below.
# And a cheatsheet link for the Jupyter Notebook.
# </div>
#
# ![_F4A9370.jpeg](attachment:09f8e023-cc25-4022-9fd5-d32dc682a0ce.jpeg)
